# %%
import os
import base64
import requests
from IPython.display import display, Image
from google.colab import files

pAPI_KEY='AIzaSyA2Vz75LKUi0HVj5P87vx1jAKLJzMCcDE8'

# %%
os.environ['API_KEY']=pAPI_KEY
# !echo "$API_KEY"
# Another way of assigning env Var
#%env API_KEY=AIzaSyB1UlDyJgdXhvYkRJOUPMjo-fUG62_c1w8

visionJson={
  "requests": [
      {
        "image": {
           "content": base64.b64encode(images).decode("UTF-8")
        },
        "features": [
          {
            "type": "LABEL_DETECTION",
            "maxResults": 10
          },
          {
            "type": "WEB_DETECTION",
            "maxResults": 10
          }
        ]
      }
  ]
}
# Out:
# AIzaSyA2Vz75LKUi0HVj5P87vx1jAKLJzMCcDE8

# %% [markdown]
# ## Load the image file from your local machine to see what GCP thinks are in the picture
# Click "Choose Files" button and select the file from your local machine

# %%
# !wget https://whc.unesco.org/uploads/thumbs/site_0252_0001-500-375-20080319163058.jpg
# Out:
# --2019-05-05 21:00:53--  https://whc.unesco.org/uploads/thumbs/site_0252_0001-500-375-20080319163058.jpg
# Resolving whc.unesco.org (whc.unesco.org)... 193.242.192.43
# Connecting to whc.unesco.org (whc.unesco.org)|193.242.192.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24692 (24K) [image/jpeg]
# Saving to: ‘site_0252_0001-500-375-20080319163058.jpg’
#
# site_0252_0001-500- 100%[===================>]  24.11K  --.-KB/s    in 0s
#
# 2019-05-05 21:00:54 (158 MB/s) - ‘site_0252_0001-500-375-20080319163058.jpg’ saved [24692/24692]

# %%
# !ls
# Out:
# 1092px-Taj_Mahal_in_March_2004.jpg  site_0252_0001-500-375-20080319163058.jpg
# sample_data

# %%
display(Image(filename="site_0252_0001-500-375-20080319163058.jpg"))

# %%
  with open(filename, 'rb') as image_file:
    images = image_file.read()
visionResp = requests.post('https://vision.googleapis.com/v1/images:annotate?key={0}'.format(pAPI_KEY), json=visionJson)
print(visionResp.text)

# %%
uploaded = files.upload()
# Keep only the last file for vision recognition
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  filename = fn

  with open(filename, 'rb') as image_file:
    images = image_file.read()
# Out:
#      <input type="file" id="files-3ef842ca-c511-4986-b703-e1e9d6ffc3af" name="files[]" multiple disabled />
#      <output id="result-3ef842ca-c511-4986-b703-e1e9d6ffc3af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1092px-Taj_Mahal_in_March_2004.jpg to 1092px-Taj_Mahal_in_March_2004.jpg
# User uploaded file "1092px-Taj_Mahal_in_March_2004.jpg" with length 265048 bytes

# %%
display(Image(filename=filename))

# %% [markdown]
# REST API - Using curl from shell environment

# %%
visionResp = requests.post('https://vision.googleapis.com/v1/images:annotate?key={0}'.format(pAPI_KEY), json=visionJson)
print(visionResp.text)

raise Exception("Stop to look at the results!!!")
# Out:
# {
#   "responses": [
#     {
#       "labelAnnotations": [
#         {
#           "mid": "/m/05_5t0l",
#           "description": "Landmark",
#           "score": 0.9855491,
#           "topicality": 0.9855491
#         },
#         {
#           "mid": "/m/02y_3gd",
#           "description": "Wonders of the world",
#           "score": 0.9600558,
#           "topicality": 0.9600558
#         },
#         {
#           "mid": "/m/07yr8h",
#           "description": "Historic site",
#           "score": 0.95168465,
#           "topicality": 0.95168465
#         },
#         {
#           "mid": "/m/02ljgl",
#           "description": "Monument",
#           "score": 0.93388706,
#           "topicality": 0.93388706
#         },
#         {
#           "mid": "/m/0pgl9",
#           "description": "Tourist attraction",
#           "score": 0.9081159,
#           "topicality": 0.9081159
#         },
#         {
#           "mid": "/m/065zs54",
#           "description": "Holy places",
#           "score": 0.9002917,
#           "topicality": 0.9002917
#         },
#         {
#           "mid": "/m/0c85fd",
#           "description": "Dome",
#           "score": 0.8909633,
#           "topicality": 0.8909633
#         },
#         {
#           "mid": "/m/03nfmq",
#           "description": "Architecture",
#           "score": 0.86487967,
#           "topicality": 0.86487967
#         },
#         {
#           "mid": "/m/0cgh4",
#           "description": "Building",
#           "score": 0.7888285,
#           "topicality": 0.7888285
#         },
#         {
#           "mid": "/m/0c7g7",
#           "description": "Unesco world heritage site",
#           "score": 0.78468925,
#           "topicality": 0.78468925
#         }
#       ],
#       "webDetection": {
#         "webEntities": [
#           {
#             "entityId": "/m/0l8cb",
#             "score": 1.9040623,
#             "description": "Taj Mahal"
#           },
#           {
#             "entityId": "/m/0vzr6t1",
#             "score": 1.0213499,
#             "description": "Black Taj Mahal"
#           },
#           {
#             "entityId": "/g/11dzd5r15h",
#             "score": 0.46185702,
#             "description": "One Day Taj Mahal Tour"
#           },
#           {
#             "entityId": "/t/21mxcct4492j5",
#             "score": 0.3715
#           },
#           {
#             "entityId": "/m/014dsx",
#             "score": 0.3628,
#             "description": "Travel"
#           },
#           {
#             "entityId": "/g/1pp2t_v76",
#             "score": 0.34775403,
#             "description": "India Tour"
#           },
#           {
#             "entityId": "/m/053yxh",
#             "score": 0.2822,
#             "description": "Mughal gardens"
#           },
#           {
#             "entityId": "/m/02ljgl",
#             "score": 0.2767,
#             "description": "Monument"
#           },
#           {
#             "entityId": "/g/120yrv6h",
#             "score": 0.2476,
#             "description": "Tourism"
#           },
#           {
#             "entityId": "/m/01hmml",
#             "score": 0.2459,
#             "description": "Mausoleum"
#           }
#         ],
#         "fullMatchingImages": [
#           {
#             "url": "https://media04.meinbezirk.at/article/2018/10/11/2/16321932_XXL.jpg"
#           },
#           {
#             "url": "https://statics-uestudio.uecdn.es/buhomag/2016/04/15001246/taj.jpg?ixlib=php-1.1.0"
#           },
#           {
#             "url": "http://www.beyondboundaries.in/media/25284/images/BEYOND%20BOUNDARIES%20-%20PENSA%20IMAGES_html_5d08d957.jpg"
#           },
#           {
#             "url": "http://plantasyjardin.com/wp-content/uploads/2011/09/Taj_Mahal_in_March_2004.jpg"
#           },
#           {
#             "url": "x-raw-image:///d45e16a9f3bdb003feb96bbc9a0321435f85d791954458cee1cee554da6b8382"
#           },
#           {
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c8/Taj_Mahal_in_March_2004.jpg"
#           },
#           {
#             "url": "http://monishborah.com/wp-content/uploads/2016/10/taj_mahal_in_march_2004.jpg"
#           },
#           {
#             "url": "https://uromojo.com/wp-content/uploads/2019/04/Webp.net-compress-image-1.jpg"
#           },
#           {
#             "url": "https://www.cotidianul.ro/wp-content/uploads/2018/01/03/Taj_Mahal_in_March_2004.jpg"
#           },
#           {
#             "url": "https://matthewrettino.files.wordpress.com/2019/04/taj-mahal.jpg"
#           }
#         ],
#         "partialMatchingImages": [
#           {
#             "url": "https://i2.wp.com/www.yerigeldi.com/wp-content/uploads/2014/05/delhi2.jpg?fit=2000%2C1648&ssl=1"
#           },
#           {
#             "url": "https://i.pinimg.com/originals/7c/af/f1/7caff19a0369470e0b85488c4fcd5be3.jpg"
#           },
#           {
#             "url": "https://k34.kn3.net/taringa/D/0/0/A/F/0/zagitari/E5B.jpg"
#           },
#           {
#             "url": "http://4.bp.blogspot.com/-JMd5zrgsPpA/UschMC_oUeI/AAAAAAAABHQ/FlKNkWRNwww/s1600/Taj_Mahal_in_March_2004.jpg"
#           },
#           {
#             "url": "http://1.bp.blogspot.com/-S23pvCKDPxk/Uxt9Uh1_7MI/AAAAAAAAABo/YBiDxFJXjK4/s1600/Taj_Mahal_in_March_2004.jpg"
#           },
#           {
#             "url": "http://3.bp.blogspot.com/-wzreib2f3wo/ThGQdoYdh7I/AAAAAAAAARE/3KfZ2WqHUao/s1600/New%20Seven%20Wonders%20of%20the%20World%2007a.jpg"
#           },
#           {
#             "url": "http://2.bp.blogspot.com/-djaXg6ZogTA/UC0KEBWAHYI/AAAAAAAAABo/H_kzHeu8tx4/s1600/Taj_Mahal.jpg"
#           },
#           {
#             "url": "http://1.bp.blogspot.com/-o3lN1Uyv2Us/UiYpDqnWTJI/AAAAAAAACqY/Xi9a-8GNpH0/s1600/Taj_Mahal.jpg"
#           },
#           {
#             "url": "http://krishna.org/wp-content/uploads/2000/09/Taj_Mahal_in_March_2004.jpg"
#           },
#           {
#             "url": "https://netwallcraft.com/wp-content/uploads/2018/10/mosque-a-muslim-place-of-worship-large-where-is-taj-mahal-in-india-map-of-where-is-taj-mahal-in-india-map.jpg"
#           }
#         ],
#         "pagesWithMatchingImages": [
#           {
#             "url": "https://en.wikipedia.org/wiki/Taj_Mahal",
#             "pageTitle": "\u003cb\u003eTaj Mahal\u003c/b\u003e - Wikipedia",
#             "fullMatchingImages": [
#               {
#                 "url": "https://upload.wikimedia.org/wikipedia/commons/c/c8/Taj_Mahal_in_March_2004.jpg"
#               }
#             ]
#           },
#           {
#             "url": "https://en.wikipedia.org/wiki/Origins_and_architecture_of_the_Taj_Mahal",
#             "pageTitle": "Origins and architecture of the \u003cb\u003eTaj Mahal\u003c/b\u003e - Wikipedia"
#           },
#           {
#             "url": "https://en.wikipedia.org/wiki/Black_Taj_Mahal",
#             "pageTitle": "Black \u003cb\u003eTaj Mahal\u003c/b\u003e - Wikipedia"
#           },
#           {
#             "url": "https://en.wikipedia.org/wiki/Taj_Mahal_(disambiguation)",
#             "pageTitle": "\u003cb\u003eTaj Mahal\u003c/b\u003e (disambiguation) - Wikipedia"
#           },
#           {
#             "url": "http://uncyclopedia.wikia.com/wiki/Taj_Mahal",
#             "pageTitle": "\u003cb\u003eTaj Mahal\u003c/b\u003e | Uncyclopedia | FANDOM powered by Wikia",
#             "partialMatchingImages": [
#               {
#                 "url": "https://vignette.wikia.nocookie.net/uncyclopedia/images/0/0c/Taj-mahal.jpg/revision/latest/scale-to-width-down/728?cb=20140326153323"
#               }
#             ]
#           },
#           {
#             "url": "https://www.ancient-origins.net/taj-mahal-agra-india-006252",
#             "pageTitle": "\u003cb\u003eTaj Mahal\u003c/b\u003e, Agra, India | Ancient Origins",
#             "fullMatchingImages": [
#               {
#                 "url": "https://www.ancient-origins.net/sites/default/files/taj.jpg"
#               }
#             ]
#           },
#           {
#             "url": "https://www.wildriverreview.com/archives/wonder-taj-mahal-seen-author-sandra-wilson/",
#             "pageTitle": "The Wonder of the \u003cb\u003eTaj Mahal\u003c/b\u003e as Seen by Author Sandra Wilson ...",
#             "fullMatchingImages": [
#               {
#                 "url": "http://www.wildriverreview.co/wp-content/uploads/2016/08/taj-mahal.png"
#               },
#               {
#                 "url": "https://i2.wp.com/www.wildriverreview.co/wp-content/uploads/2016/08/taj-mahal.png"
#               }
#             ]
#           },
#           {
#             "url": "https://www.eturbonews.com/tag/taj-mahal",
#             "pageTitle": "\u003cb\u003eTaj Mahal\u003c/b\u003e | Travel News | eTurboNews",
#             "fullMatchingImages": [
#               {
#                 "url": "https://www.eturbonews.com/wp-content/uploads/2017/03/00_1212374973.jpg"
#               }
#             ]
#           },
#           {
#             "url": "https://thisgirlabroad.com/highlights-taj-mahal/",
#             "pageTitle": "Highlights of the \u003cb\u003eTaj Mahal\u003c/b\u003e - thisgirlabroad",
#             "fullMatchingImages": [
#               {
#                 "url": "https://thisgirlabroad.com/wp-content/uploads/2017/10/TajMahal_2.jpg"
#               }
#             ]
#           },
#           {
#             "url": "https://www.quora.com/Who-is-the-best-service-provider-for-Taj-Mahal-tours",
#             "pageTitle": "Who is the best service provider for \u003cb\u003eTaj Mahal\u003c/b\u003e tours? - Quora",
#             "partialMatchingImages": [
#               {
#                 "url": "https://qph.fs.quoracdn.net/main-qimg-7ba2a163d7aa0eeb7c9e060e1befdeb6"
#               }
#             ]
#           }
#         ],
#         "visuallySimilarImages": [
#           {
#             "url": "http://www.indiareview.co.uk/wp-content/uploads/2018/06/7_ir-new1.jpg"
#           },
#           {
#             "url": "https://akm-img-a-in.tosshub.com/indiatoday/images/story/201710/taj-mahal_647_101817042642_0.jpg"
#           },
#           {
#             "url": "http://www.joy-travels.com/Siteadmin/cat_image/87ce9499cee1cab285c19b7f1856a3f5.jpg"
#           },
#           {
#             "url": "https://media.istockphoto.com/photos/taj-mahal-picture-id89445800?k=6&m=89445800&s=612x612&w=0&h=nnXEJ8MsJwTjlOJuixMT5SOpbxM0dAr2w1EfllrVbQk="
#           },
#           {
#             "url": "http://www.upnri.com/writereaddata/Portal/Images/taj-mahal.jpg"
#           },
#           {
#             "url": "https://image.shutterstock.com/image-photo/taj-mahal-agra-india-260nw-285748187.jpg"
#           },
#           {
#             "url": "http://summerlandtravels.com/wp-content/uploads/2017/09/taj-mahal.jpg"
#           },
#           {
#             "url": "https://image.shutterstock.com/image-photo/taj-mahal-india-260nw-56550682.jpg"
#           }
#         ],
#         "bestGuessLabels": [
#           {
#             "label": "taj mahal"
#           }
#         ]
#       }
#     }
#   ]
# }
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-4e3517cb9548> in <module>()
#      22 print(visionResp.text)
#      23
# ---> 24 raise Exception("Stop to look at the results!!!")
#
# Exception: Stop to look at the results!!!

# %% [markdown]
# ##Upload image and try facial recognition and landmark identification

# %%
uploaded = files.upload()
# Keep only the last file for vision recognition
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  filename = fn

  with open(filename, 'rb') as image_file:
    images = image_file.read()
# Out:
#      <input type="file" id="files-5032d453-8dc5-4eaf-a8c2-15f5c7782a82" name="files[]" multiple disabled />
#      <output id="result-5032d453-8dc5-4eaf-a8c2-15f5c7782a82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving GoogleSample.jpg to GoogleSample.jpg
# User uploaded file "GoogleSample.jpg" with length 122578 bytes

# %%
faceJson={
  "requests": [
      {
        "image": {
           "content": base64.b64encode(images).decode("UTF-8")
        },
        "features": [
          {
            "type": "FACE_DETECTION"
          },
          {
            "type": "LANDMARK_DETECTION"
          }
        ]
      }
  ]
}

faceResp = requests.post('https://vision.googleapis.com/v1/images:annotate?key={0}'.format(pAPI_KEY), json=faceJson)
print(faceResp.text)

raise Exception("Stop to look at the results!!!")
# Out:
# {
#   "responses": [
#     {
#       "faceAnnotations": [
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 669,
#                 "y": 324
#               },
#               {
#                 "x": 760,
#                 "y": 324
#               },
#               {
#                 "x": 760,
#                 "y": 430
#               },
#               {
#                 "x": 669,
#                 "y": 430
#               }
#             ]
#           },
#           "fdBoundingPoly": {
#             "vertices": [
#               {
#                 "x": 675,
#                 "y": 354
#               },
#               {
#                 "x": 735,
#                 "y": 354
#               },
#               {
#                 "x": 735,
#                 "y": 414
#               },
#               {
#                 "x": 675,
#                 "y": 414
#               }
#             ]
#           },
#           "landmarks": [
#             {
#               "type": "LEFT_EYE",
#               "position": {
#                 "x": 692.05646,
#                 "y": 372.95868,
#                 "z": -0.0002526854
#               }
#             },
#             {
#               "type": "RIGHT_EYE",
#               "position": {
#                 "x": 717.7477,
#                 "y": 372.9084,
#                 "z": -10.85004
#               }
#             },
#             {
#               "type": "LEFT_OF_LEFT_EYEBROW",
#               "position": {
#                 "x": 684.4492,
#                 "y": 366.2851,
#                 "z": 5.824417
#               }
#             },
#             {
#               "type": "RIGHT_OF_LEFT_EYEBROW",
#               "position": {
#                 "x": 696.2992,
#                 "y": 366.59366,
#                 "z": -7.7937016
#               }
#             },
#             {
#               "type": "LEFT_OF_RIGHT_EYEBROW",
#               "position": {
#                 "x": 708.5379,
#                 "y": 366.7713,
#                 "z": -13.004163
#               }
#             },
#             {
#               "type": "RIGHT_OF_RIGHT_EYEBROW",
#               "position": {
#                 "x": 726.5456,
#                 "y": 366.92877,
#                 "z": -12.083326
#               }
#             },
#             {
#               "type": "MIDPOINT_BETWEEN_EYES",
#               "position": {
#                 "x": 702.2475,
#                 "y": 372.4972,
#                 "z": -10.5965395
#               }
#             },
#             {
#               "type": "NOSE_TIP",
#               "position": {
#                 "x": 699.05286,
#                 "y": 388.38126,
#                 "z": -17.563484
#               }
#             },
#             {
#               "type": "UPPER_LIP",
#               "position": {
#                 "x": 701.245,
#                 "y": 398.7124,
#                 "z": -11.386475
#               }
#             },
#             {
#               "type": "LOWER_LIP",
#               "position": {
#                 "x": 702.2174,
#                 "y": 407.44824,
#                 "z": -9.299454
#               }
#             },
#             {
#               "type": "MOUTH_LEFT",
#               "position": {
#                 "x": 693.4581,
#                 "y": 401.6477,
#                 "z": 0.03429009
#               }
#             },
#             {
#               "type": "MOUTH_RIGHT",
#               "position": {
#                 "x": 716.83954,
#                 "y": 400.81027,
#                 "z": -8.433873
#               }
#             },
#             {
#               "type": "MOUTH_CENTER",
#               "position": {
#                 "x": 701.671,
#                 "y": 402.3624,
#                 "z": -9.415283
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_RIGHT",
#               "position": {
#                 "x": 709.21423,
#                 "y": 390.45886,
#                 "z": -10.728386
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_LEFT",
#               "position": {
#                 "x": 696.24554,
#                 "y": 390.02206,
#                 "z": -4.8575044
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_CENTER",
#               "position": {
#                 "x": 701.87756,
#                 "y": 392.6657,
#                 "z": -11.612123
#               }
#             },
#             {
#               "type": "LEFT_EYE_TOP_BOUNDARY",
#               "position": {
#                 "x": 691.178,
#                 "y": 371.07794,
#                 "z": -1.6994492
#               }
#             },
#             {
#               "type": "LEFT_EYE_RIGHT_CORNER",
#               "position": {
#                 "x": 696.99115,
#                 "y": 373.35028,
#                 "z": -1.9849461
#               }
#             },
#             {
#               "type": "LEFT_EYE_BOTTOM_BOUNDARY",
#               "position": {
#                 "x": 691.8553,
#                 "y": 374.78043,
#                 "z": -0.11956799
#               }
#             },
#             {
#               "type": "LEFT_EYE_LEFT_CORNER",
#               "position": {
#                 "x": 687.85114,
#                 "y": 372.87338,
#                 "z": 4.5108714
#               }
#             },
#             {
#               "type": "LEFT_EYE_PUPIL",
#               "position": {
#                 "x": 691.1986,
#                 "y": 372.9344,
#                 "z": -0.39302823
#               }
#             },
#             {
#               "type": "RIGHT_EYE_TOP_BOUNDARY",
#               "position": {
#                 "x": 716.37085,
#                 "y": 371.4634,
#                 "z": -12.40188
#               }
#             },
#             {
#               "type": "RIGHT_EYE_RIGHT_CORNER",
#               "position": {
#                 "x": 723.07336,
#                 "y": 373.40768,
#                 "z": -10.454721
#               }
#             },
#             {
#               "type": "RIGHT_EYE_BOTTOM_BOUNDARY",
#               "position": {
#                 "x": 716.8877,
#                 "y": 375.11426,
#                 "z": -10.801529
#               }
#             },
#             {
#               "type": "RIGHT_EYE_LEFT_CORNER",
#               "position": {
#                 "x": 711.8931,
#                 "y": 373.45593,
#                 "z": -8.378084
#               }
#             },
#             {
#               "type": "RIGHT_EYE_PUPIL",
#               "position": {
#                 "x": 717.04047,
#                 "y": 373.33057,
#                 "z": -11.421103
#               }
#             },
#             {
#               "type": "LEFT_EYEBROW_UPPER_MIDPOINT",
#               "position": {
#                 "x": 689.58,
#                 "y": 363.13654,
#                 "z": -2.7445116
#               }
#             },
#             {
#               "type": "RIGHT_EYEBROW_UPPER_MIDPOINT",
#               "position": {
#                 "x": 716.9182,
#                 "y": 363.54892,
#                 "z": -14.362484
#               }
#             },
#             {
#               "type": "LEFT_EAR_TRAGION",
#               "position": {
#                 "x": 689.0497,
#                 "y": 385.31052,
#                 "z": 38.497536
#               }
#             },
#             {
#               "type": "RIGHT_EAR_TRAGION",
#               "position": {
#                 "x": 747.31775,
#                 "y": 386.05096,
#                 "z": 14.426956
#               }
#             },
#             {
#               "type": "FOREHEAD_GLABELLA",
#               "position": {
#                 "x": 701.9971,
#                 "y": 366.36548,
#                 "z": -11.372161
#               }
#             },
#             {
#               "type": "CHIN_GNATHION",
#               "position": {
#                 "x": 703.7108,
#                 "y": 419.66806,
#                 "z": -5.4058967
#               }
#             },
#             {
#               "type": "CHIN_LEFT_GONION",
#               "position": {
#                 "x": 687.40045,
#                 "y": 403.02136,
#                 "z": 27.55279
#               }
#             },
#             {
#               "type": "CHIN_RIGHT_GONION",
#               "position": {
#                 "x": 739.1988,
#                 "y": 403.8794,
#                 "z": 5.509255
#               }
#             }
#           ],
#           "rollAngle": 0.21619819,
#           "panAngle": -23.02797,
#           "tiltAngle": -1.5531756,
#           "detectionConfidence": 0.72354823,
#           "landmarkingConfidence": 0.20047489,
#           "joyLikelihood": "POSSIBLE",
#           "sorrowLikelihood": "VERY_UNLIKELY",
#           "angerLikelihood": "VERY_UNLIKELY",
#           "surpriseLikelihood": "VERY_UNLIKELY",
#           "underExposedLikelihood": "VERY_UNLIKELY",
#           "blurredLikelihood": "VERY_UNLIKELY",
#           "headwearLikelihood": "VERY_LIKELY"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 85,
#                 "y": 426
#               },
#               {
#                 "x": 467,
#                 "y": 426
#               },
#               {
#                 "x": 467,
#                 "y": 871
#               },
#               {
#                 "x": 85,
#                 "y": 871
#               }
#             ]
#           },
#           "fdBoundingPoly": {
#             "vertices": [
#               {
#                 "x": 106,
#                 "y": 537
#               },
#               {
#                 "x": 441,
#                 "y": 537
#               },
#               {
#                 "x": 441,
#                 "y": 872
#               },
#               {
#                 "x": 106,
#                 "y": 872
#               }
#             ]
#           },
#           "landmarks": [
#             {
#               "type": "LEFT_EYE",
#               "position": {
#                 "x": 220.1872,
#                 "y": 638.2954,
#                 "z": -0.00013366595
#               }
#             },
#             {
#               "type": "RIGHT_EYE",
#               "position": {
#                 "x": 335.80832,
#                 "y": 641.8185,
#                 "z": 0.57039523
#               }
#             },
#             {
#               "type": "LEFT_OF_LEFT_EYEBROW",
#               "position": {
#                 "x": 182.38551,
#                 "y": 608.7605,
#                 "z": 7.420773
#               }
#             },
#             {
#               "type": "RIGHT_OF_LEFT_EYEBROW",
#               "position": {
#                 "x": 250.94044,
#                 "y": 613.97815,
#                 "z": -25.401297
#               }
#             },
#             {
#               "type": "LEFT_OF_RIGHT_EYEBROW",
#               "position": {
#                 "x": 307.05093,
#                 "y": 615.59827,
#                 "z": -25.144073
#               }
#             },
#             {
#               "type": "RIGHT_OF_RIGHT_EYEBROW",
#               "position": {
#                 "x": 375.48718,
#                 "y": 614.43286,
#                 "z": 8.354321
#               }
#             },
#             {
#               "type": "MIDPOINT_BETWEEN_EYES",
#               "position": {
#                 "x": 278.42282,
#                 "y": 636.2649,
#                 "z": -24.594847
#               }
#             },
#             {
#               "type": "NOSE_TIP",
#               "position": {
#                 "x": 276.20016,
#                 "y": 709.5746,
#                 "z": -50.706635
#               }
#             },
#             {
#               "type": "UPPER_LIP",
#               "position": {
#                 "x": 275.02386,
#                 "y": 747.4613,
#                 "z": -19.15356
#               }
#             },
#             {
#               "type": "LOWER_LIP",
#               "position": {
#                 "x": 273.90552,
#                 "y": 786.6168,
#                 "z": -6.2561064
#               }
#             },
#             {
#               "type": "MOUTH_LEFT",
#               "position": {
#                 "x": 227.00937,
#                 "y": 757.92834,
#                 "z": 14.062568
#               }
#             },
#             {
#               "type": "MOUTH_RIGHT",
#               "position": {
#                 "x": 324.6917,
#                 "y": 758.30756,
#                 "z": 15.156286
#               }
#             },
#             {
#               "type": "MOUTH_CENTER",
#               "position": {
#                 "x": 274.85626,
#                 "y": 765.8013,
#                 "z": -8.384632
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_RIGHT",
#               "position": {
#                 "x": 308.7482,
#                 "y": 713.3633,
#                 "z": -5.05042
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_LEFT",
#               "position": {
#                 "x": 243.35995,
#                 "y": 713.08704,
#                 "z": -5.2631865
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_CENTER",
#               "position": {
#                 "x": 275.78268,
#                 "y": 725.1536,
#                 "z": -22.125332
#               }
#             },
#             {
#               "type": "LEFT_EYE_TOP_BOUNDARY",
#               "position": {
#                 "x": 220.59596,
#                 "y": 631.1835,
#                 "z": -8.668753
#               }
#             },
#             {
#               "type": "LEFT_EYE_RIGHT_CORNER",
#               "position": {
#                 "x": 242.8134,
#                 "y": 640.2789,
#                 "z": 0.6842047
#               }
#             },
#             {
#               "type": "LEFT_EYE_BOTTOM_BOUNDARY",
#               "position": {
#                 "x": 219.90852,
#                 "y": 646.19104,
#                 "z": -0.12689543
#               }
#             },
#             {
#               "type": "LEFT_EYE_LEFT_CORNER",
#               "position": {
#                 "x": 197.30377,
#                 "y": 636.79987,
#                 "z": 10.471473
#               }
#             },
#             {
#               "type": "LEFT_EYE_PUPIL",
#               "position": {
#                 "x": 218.51605,
#                 "y": 638.47107,
#                 "z": -2.9172459
#               }
#             },
#             {
#               "type": "RIGHT_EYE_TOP_BOUNDARY",
#               "position": {
#                 "x": 336.18198,
#                 "y": 634.5311,
#                 "z": -8.105895
#               }
#             },
#             {
#               "type": "RIGHT_EYE_RIGHT_CORNER",
#               "position": {
#                 "x": 358.8801,
#                 "y": 641.47675,
#                 "z": 11.252687
#               }
#             },
#             {
#               "type": "RIGHT_EYE_BOTTOM_BOUNDARY",
#               "position": {
#                 "x": 335.6239,
#                 "y": 649.5006,
#                 "z": 0.41631728
#               }
#             },
#             {
#               "type": "RIGHT_EYE_LEFT_CORNER",
#               "position": {
#                 "x": 312.46457,
#                 "y": 642.3819,
#                 "z": 0.98882556
#               }
#             },
#             {
#               "type": "RIGHT_EYE_PUPIL",
#               "position": {
#                 "x": 337.16272,
#                 "y": 641.9324,
#                 "z": -2.4989882
#               }
#             },
#             {
#               "type": "LEFT_EYEBROW_UPPER_MIDPOINT",
#               "position": {
#                 "x": 216.72218,
#                 "y": 598.16785,
#                 "z": -18.23109
#               }
#             },
#             {
#               "type": "RIGHT_EYEBROW_UPPER_MIDPOINT",
#               "position": {
#                 "x": 342.1192,
#                 "y": 601.7854,
#                 "z": -17.605368
#               }
#             },
#             {
#               "type": "LEFT_EAR_TRAGION",
#               "position": {
#                 "x": 144.98914,
#                 "y": 676.6305,
#                 "z": 147.86142
#               }
#             },
#             {
#               "type": "RIGHT_EAR_TRAGION",
#               "position": {
#                 "x": 407.576,
#                 "y": 684.291,
#                 "z": 149.1233
#               }
#             },
#             {
#               "type": "FOREHEAD_GLABELLA",
#               "position": {
#                 "x": 279.06616,
#                 "y": 613.7934,
#                 "z": -29.803047
#               }
#             },
#             {
#               "type": "CHIN_GNATHION",
#               "position": {
#                 "x": 272.37708,
#                 "y": 836.28076,
#                 "z": 15.637695
#               }
#             },
#             {
#               "type": "CHIN_LEFT_GONION",
#               "position": {
#                 "x": 155.52937,
#                 "y": 755.86255,
#                 "z": 109.27146
#               }
#             },
#             {
#               "type": "CHIN_RIGHT_GONION",
#               "position": {
#                 "x": 392.8323,
#                 "y": 762.7853,
#                 "z": 110.427895
#               }
#             }
#           ],
#           "rollAngle": 1.6801219,
#           "panAngle": 0.28368974,
#           "tiltAngle": -6.298056,
#           "detectionConfidence": 0.98864377,
#           "landmarkingConfidence": 0.18741898,
#           "joyLikelihood": "VERY_LIKELY",
#           "sorrowLikelihood": "VERY_UNLIKELY",
#           "angerLikelihood": "VERY_UNLIKELY",
#           "surpriseLikelihood": "VERY_UNLIKELY",
#           "underExposedLikelihood": "VERY_UNLIKELY",
#           "blurredLikelihood": "VERY_UNLIKELY",
#           "headwearLikelihood": "VERY_LIKELY"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 745,
#                 "y": 450
#               },
#               {
#                 "x": 886,
#                 "y": 450
#               },
#               {
#                 "x": 886,
#                 "y": 614
#               },
#               {
#                 "x": 745,
#                 "y": 614
#               }
#             ]
#           },
#           "fdBoundingPoly": {
#             "vertices": [
#               {
#                 "x": 756,
#                 "y": 500
#               },
#               {
#                 "x": 876,
#                 "y": 500
#               },
#               {
#                 "x": 876,
#                 "y": 619
#               },
#               {
#                 "x": 756,
#                 "y": 619
#               }
#             ]
#           },
#           "landmarks": [
#             {
#               "type": "LEFT_EYE",
#               "position": {
#                 "x": 795.2683,
#                 "y": 540.1295,
#                 "z": -0.00034131587
#               }
#             },
#             {
#               "type": "RIGHT_EYE",
#               "position": {
#                 "x": 838.8197,
#                 "y": 535.54346,
#                 "z": 1.083428
#               }
#             },
#             {
#               "type": "LEFT_OF_LEFT_EYEBROW",
#               "position": {
#                 "x": 780.06946,
#                 "y": 530.80524,
#                 "z": 0.18970883
#               }
#             },
#             {
#               "type": "RIGHT_OF_LEFT_EYEBROW",
#               "position": {
#                 "x": 805.75385,
#                 "y": 531.9873,
#                 "z": -10.820261
#               }
#             },
#             {
#               "type": "LEFT_OF_RIGHT_EYEBROW",
#               "position": {
#                 "x": 826.2505,
#                 "y": 529.98706,
#                 "z": -10.284787
#               }
#             },
#             {
#               "type": "RIGHT_OF_RIGHT_EYEBROW",
#               "position": {
#                 "x": 850.6104,
#                 "y": 523.9195,
#                 "z": 2.0552828
#               }
#             },
#             {
#               "type": "MIDPOINT_BETWEEN_EYES",
#               "position": {
#                 "x": 816.94275,
#                 "y": 538.88885,
#                 "z": -8.501295
#               }
#             },
#             {
#               "type": "NOSE_TIP",
#               "position": {
#                 "x": 819.5479,
#                 "y": 566.6245,
#                 "z": -12.472598
#               }
#             },
#             {
#               "type": "UPPER_LIP",
#               "position": {
#                 "x": 819.75867,
#                 "y": 577.23773,
#                 "z": 1.5866246
#               }
#             },
#             {
#               "type": "LOWER_LIP",
#               "position": {
#                 "x": 821.6677,
#                 "y": 592.2127,
#                 "z": 9.757308
#               }
#             },
#             {
#               "type": "MOUTH_LEFT",
#               "position": {
#                 "x": 800.74994,
#                 "y": 579.83185,
#                 "z": 14.53717
#               }
#             },
#             {
#               "type": "MOUTH_RIGHT",
#               "position": {
#                 "x": 839.99023,
#                 "y": 576.3258,
#                 "z": 15.661866
#               }
#             },
#             {
#               "type": "MOUTH_CENTER",
#               "position": {
#                 "x": 820.2752,
#                 "y": 584.20624,
#                 "z": 7.0678606
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_RIGHT",
#               "position": {
#                 "x": 830.94324,
#                 "y": 563.6127,
#                 "z": 4.5108185
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_LEFT",
#               "position": {
#                 "x": 806.2289,
#                 "y": 565.69257,
#                 "z": 3.9439883
#               }
#             },
#             {
#               "type": "NOSE_BOTTOM_CENTER",
#               "position": {
#                 "x": 819.4519,
#                 "y": 569.8289,
#                 "z": -1.1284136
#               }
#             },
#             {
#               "type": "LEFT_EYE_TOP_BOUNDARY",
#               "position": {
#                 "x": 795.2146,
#                 "y": 538.233,
#                 "z": -3.6923947
#               }
#             },
#             {
#               "type": "LEFT_EYE_RIGHT_CORNER",
#               "position": {
#                 "x": 803.71045,
#                 "y": 539.7313,
#                 "z": 0.4766285
#               }
#             },
#             {
#               "type": "LEFT_EYE_BOTTOM_BOUNDARY",
#               "position": {
#                 "x": 795.55927,
#                 "y": 542.9382,
#                 "z": 0.51118195
#               }
#             },
#             {
#               "type": "LEFT_EYE_LEFT_CORNER",
#               "position": {
#                 "x": 786.6779,
#                 "y": 539.8564,
#                 "z": 3.487713
#               }
#             },
#             {
#               "type": "LEFT_EYE_PUPIL",
#               "position": {
#                 "x": 794.6569,
#                 "y": 540.50604,
#                 "z": -1.1093899
#               }
#             },
#             {
#               "type": "RIGHT_EYE_TOP_BOUNDARY",
#               "position": {
#                 "x": 837.426,
#                 "y": 534.113,
#                 "z": -2.5722494
#               }
#             },
#             {
#               "type": "RIGHT_EYE_RIGHT_CORNER",
#               "position": {
#                 "x": 845.71454,
#                 "y": 534.0971,
#                 "z": 5.058714
#               }
#             },
#             {
#               "type": "RIGHT_EYE_BOTTOM_BOUNDARY",
#               "position": {
#                 "x": 837.79944,
#                 "y": 538.8426,
#                 "z": 1.6351256
#               }
#             },
#             {
#               "type": "RIGHT_EYE_LEFT_CORNER",
#               "position": {
#                 "x": 829.1851,
#                 "y": 537.70807,
#                 "z": 1.2066321
#               }
#             },
#             {
#               "type": "RIGHT_EYE_PUPIL",
#               "position": {
#                 "x": 837.99976,
#                 "y": 536.31714,
#                 "z": -0.020853035
#               }
#             },
#             {
#               "type": "LEFT_EYEBROW_UPPER_MIDPOINT",
#               "position": {
#                 "x": 792.4835,
#                 "y": 527.3755,
#                 "z": -9.6801405
#               }
#             },
#             {
#               "type": "RIGHT_EYEBROW_UPPER_MIDPOINT",
#               "position": {
#                 "x": 838.27576,
#                 "y": 522.91046,
#                 "z": -8.46897
#               }
#             },
#             {
#               "type": "LEFT_EAR_TRAGION",
#               "position": {
#                 "x": 767.26855,
#                 "y": 546.09326,
#                 "z": 55.599873
#               }
#             },
#             {
#               "type": "RIGHT_EAR_TRAGION",
#               "position": {
#                 "x": 863.152,
#                 "y": 536.71295,
#                 "z": 58.08622
#               }
#             },
#             {
#               "type": "FOREHEAD_GLABELLA",
#               "position": {
#                 "x": 816.03687,
#                 "y": 530.975,
#                 "z": -12.2784195
#               }
#             },
#             {
#               "type": "CHIN_GNATHION",
#               "position": {
#                 "x": 822.5753,
#                 "y": 607.1006,
#                 "z": 20.960659
#               }
#             },
#             {
#               "type": "CHIN_LEFT_GONION",
#               "position": {
#                 "x": 775.16174,
#                 "y": 576.6841,
#                 "z": 47.856
#               }
#             },
#             {
#               "type": "CHIN_RIGHT_GONION",
#               "position": {
#                 "x": 861.7816,
#                 "y": 568.26685,
#                 "z": 50.14255
#               }
#             }
#           ],
#           "rollAngle": -5.0866733,
#           "panAngle": 1.5809642,
#           "tiltAngle": -18.30349,
#           "detectionConfidence": 0.9379803,
#           "landmarkingConfidence": 0.24303582,
#           "joyLikelihood": "VERY_LIKELY",
#           "sorrowLikelihood": "VERY_UNLIKELY",
#           "angerLikelihood": "VERY_UNLIKELY",
#           "surpriseLikelihood": "VERY_UNLIKELY",
#           "underExposedLikelihood": "VERY_UNLIKELY",
#           "blurredLikelihood": "VERY_UNLIKELY",
#           "headwearLikelihood": "VERY_UNLIKELY"
#         }
#       ],
#       "landmarkAnnotations": [
#         {
#           "mid": "/m/0c7zy",
#           "description": "Petra",
#           "score": 0.5703306,
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 171,
#                 "y": 64
#               },
#               {
#                 "x": 618,
#                 "y": 64
#               },
#               {
#                 "x": 618,
#                 "y": 248
#               },
#               {
#                 "x": 171,
#                 "y": 248
#               }
#             ]
#           },
#           "locations": [
#             {
#               "latLng": {
#                 "latitude": 30.323975,
#                 "longitude": 35.449361
#               }
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-d1214430e4d5> in <module>()
#      20 print(faceResp.text)
#      21
# ---> 22 raise Exception("Stop to look at the results!!!")
#
# Exception: Stop to look at the results!!!

# %% [markdown]
# ##Upload Image and try character recognition

# %%
uploaded = files.upload()
# Keep only the last file for vision recognition
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  filename = fn

  with open(filename, 'rb') as image_file:
    images = image_file.read()
# Out:
#      <input type="file" id="files-5aadf3e3-3cfc-4bfa-adc0-755b85907fc1" name="files[]" multiple disabled />
#      <output id="result-5aadf3e3-3cfc-4bfa-adc0-755b85907fc1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Menu.jpg to Menu.jpg
# User uploaded file "Menu.jpg" with length 2106096 bytes

# %%
textJson = {
  "requests": [
      {
        "image": {
           "content": base64.b64encode(images).decode("UTF-8")
        },
        "features": [
          {
            "type": "TEXT_DETECTION",
            "maxResults": 10
          }
        ]
      }
  ]
}

textResp = requests.post('https://vision.googleapis.com/v1/images:annotate?key={0}'.format(pAPI_KEY), json=textJson)
print(textResp.text)

raise Exception("Stop to look at the results!!!")
# Out:
# {
#   "responses": [
#     {
#       "textAnnotations": [
#         {
#           "locale": "zh",
#           "description": "$ 13.95\n.. $ 13.95\nj C3宮保鸡丁.\nKung Pao chicken\n-\nJC2費香肉丝\n$13.\nPork with splcy garlic\nC6 35 季豆 $ 12.95\n14.95\njr n-green beans\n$ 13.95 jC5山城毛血旺\nPig blood in chili sauLE\nced pork 11.95\nuce\n上\nre.stdi ch noodle wi\n10.95\njC9\n,.-\nMapo\ntofu\n. Fire Pot\nC10五吏肠EE Pork Intest\nBeef in flery sauce $ 13.95\nHot Pot\ny鸡\nhicker in hot pot\n313.95 丿D2干锅茶树菇 $ 14.95\njD3干锅杏鲍菇 $ 14.95\nTea tree Mushroom in hot pot\nCoprinuscomatus in hot pot\n束鸡\nn in hot\n$13.95\njD7麻辣烫锅\n14.95\nSpicy Combination hot pot\n肚\nn hot pot\n$14.95\nJD8麻辣牛腩锅\n$ 14.95\nSpicy beef stew in hot pot\n$ 14.95\nestine in hot pot\nD9酸菜鱼羊锅\n14.95\nPickled mustard with fish and lamb\noduction\n·前制竹\nEi -il: Forwardpro328@gmail.com.\nTel: 408-740-535\n",
#           "boundingPoly": {
#             "vertices": [
#               {},
#               {
#                 "x": 2156
#               },
#               {
#                 "x": 2156,
#                 "y": 2746
#               },
#               {
#                 "y": 2746
#               }
#             ]
#           }
#         },
#         {
#           "description": "$",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1638,
#                 "y": 28
#               },
#               {
#                 "x": 1667,
#                 "y": 23
#               },
#               {
#                 "x": 1673,
#                 "y": 61
#               },
#               {
#                 "x": 1644,
#                 "y": 65
#               }
#             ]
#           }
#         },
#         {
#           "description": "13.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1697,
#                 "y": 23
#               },
#               {
#                 "x": 1843,
#                 "y": -1
#               },
#               {
#                 "x": 1849,
#                 "y": 34
#               },
#               {
#                 "x": 1703,
#                 "y": 59
#               }
#             ]
#           }
#         },
#         {
#           "description": "..",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 784,
#                 "y": 230
#               },
#               {
#                 "x": 797,
#                 "y": 228
#               },
#               {
#                 "x": 797,
#                 "y": 231
#               },
#               {
#                 "x": 784,
#                 "y": 233
#               }
#             ]
#           }
#         },
#         {
#           "description": "$",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 800,
#                 "y": 171
#               },
#               {
#                 "x": 829,
#                 "y": 166
#               },
#               {
#                 "x": 835,
#                 "y": 202
#               },
#               {
#                 "x": 806,
#                 "y": 207
#               }
#             ]
#           }
#         },
#         {
#           "description": "13.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 854,
#                 "y": 163
#               },
#               {
#                 "x": 988,
#                 "y": 141
#               },
#               {
#                 "x": 994,
#                 "y": 176
#               },
#               {
#                 "x": 860,
#                 "y": 199
#               }
#             ]
#           }
#         },
#         {
#           "description": "j",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1084,
#                 "y": 119
#               },
#               {
#                 "x": 1125,
#                 "y": 112
#               },
#               {
#                 "x": 1132,
#                 "y": 155
#               },
#               {
#                 "x": 1091,
#                 "y": 161
#               }
#             ]
#           }
#         },
#         {
#           "description": "C3",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1150,
#                 "y": 113
#               },
#               {
#                 "x": 1225,
#                 "y": 101
#               },
#               {
#                 "x": 1231,
#                 "y": 136
#               },
#               {
#                 "x": 1156,
#                 "y": 149
#               }
#             ]
#           }
#         },
#         {
#           "description": "宮保鸡丁",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1248,
#                 "y": 91
#               },
#               {
#                 "x": 1503,
#                 "y": 49
#               },
#               {
#                 "x": 1510,
#                 "y": 89
#               },
#               {
#                 "x": 1255,
#                 "y": 131
#               }
#             ]
#           }
#         },
#         {
#           "description": ".",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1527,
#                 "y": 104
#               },
#               {
#                 "x": 1535,
#                 "y": 103
#               },
#               {
#                 "x": 1536,
#                 "y": 109
#               },
#               {
#                 "x": 1528,
#                 "y": 110
#               }
#             ]
#           }
#         },
#         {
#           "description": "Kung",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1261,
#                 "y": 150
#               },
#               {
#                 "x": 1351,
#                 "y": 134
#               },
#               {
#                 "x": 1357,
#                 "y": 168
#               },
#               {
#                 "x": 1267,
#                 "y": 183
#               }
#             ]
#           }
#         },
#         {
#           "description": "Pao",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1368,
#                 "y": 132
#               },
#               {
#                 "x": 1437,
#                 "y": 120
#               },
#               {
#                 "x": 1442,
#                 "y": 147
#               },
#               {
#                 "x": 1373,
#                 "y": 160
#               }
#             ]
#           }
#         },
#         {
#           "description": "chicken",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1454,
#                 "y": 118
#               },
#               {
#                 "x": 1590,
#                 "y": 94
#               },
#               {
#                 "x": 1595,
#                 "y": 122
#               },
#               {
#                 "x": 1459,
#                 "y": 146
#               }
#             ]
#           }
#         },
#         {
#           "description": "-",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 181,
#                 "y": 261
#               },
#               {
#                 "x": 259,
#                 "y": 248
#               },
#               {
#                 "x": 260,
#                 "y": 255
#               },
#               {
#                 "x": 182,
#                 "y": 268
#               }
#             ]
#           }
#         },
#         {
#           "description": "JC2",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 303,
#                 "y": 255
#               },
#               {
#                 "x": 416,
#                 "y": 236
#               },
#               {
#                 "x": 423,
#                 "y": 278
#               },
#               {
#                 "x": 310,
#                 "y": 296
#               }
#             ]
#           }
#         },
#         {
#           "description": "費",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 441,
#                 "y": 233
#               },
#               {
#                 "x": 495,
#                 "y": 224
#               },
#               {
#                 "x": 501,
#                 "y": 258
#               },
#               {
#                 "x": 447,
#                 "y": 267
#               }
#             ]
#           }
#         },
#         {
#           "description": "香",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 500,
#                 "y": 222
#               },
#               {
#                 "x": 558,
#                 "y": 212
#               },
#               {
#                 "x": 564,
#                 "y": 250
#               },
#               {
#                 "x": 506,
#                 "y": 259
#               }
#             ]
#           }
#         },
#         {
#           "description": "肉丝",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 561,
#                 "y": 212
#               },
#               {
#                 "x": 676,
#                 "y": 193
#               },
#               {
#                 "x": 682,
#                 "y": 227
#               },
#               {
#                 "x": 567,
#                 "y": 247
#               }
#             ]
#           }
#         },
#         {
#           "description": "$",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 78,
#                 "y": 310
#               },
#               {
#                 "x": 107,
#                 "y": 305
#               },
#               {
#                 "x": 113,
#                 "y": 343
#               },
#               {
#                 "x": 84,
#                 "y": 347
#               }
#             ]
#           }
#         },
#         {
#           "description": "13.",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 108,
#                 "y": 302
#               },
#               {
#                 "x": 186,
#                 "y": 289
#               },
#               {
#                 "x": 193,
#                 "y": 330
#               },
#               {
#                 "x": 115,
#                 "y": 342
#               }
#             ]
#           }
#         },
#         {
#           "description": "Pork",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 449,
#                 "y": 286
#               },
#               {
#                 "x": 527,
#                 "y": 272
#               },
#               {
#                 "x": 532,
#                 "y": 300
#               },
#               {
#                 "x": 454,
#                 "y": 314
#               }
#             ]
#           }
#         },
#         {
#           "description": "with",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 542,
#                 "y": 272
#               },
#               {
#                 "x": 610,
#                 "y": 260
#               },
#               {
#                 "x": 614,
#                 "y": 285
#               },
#               {
#                 "x": 546,
#                 "y": 297
#               }
#             ]
#           }
#         },
#         {
#           "description": "splcy",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 624,
#                 "y": 258
#               },
#               {
#                 "x": 710,
#                 "y": 243
#               },
#               {
#                 "x": 715,
#                 "y": 274
#               },
#               {
#                 "x": 630,
#                 "y": 290
#               }
#             ]
#           }
#         },
#         {
#           "description": "garlic",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 724,
#                 "y": 241
#               },
#               {
#                 "x": 816,
#                 "y": 225
#               },
#               {
#                 "x": 821,
#                 "y": 256
#               },
#               {
#                 "x": 730,
#                 "y": 273
#               }
#             ]
#           }
#         },
#         {
#           "description": "C6",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1199,
#                 "y": 672
#               },
#               {
#                 "x": 1274,
#                 "y": 661
#               },
#               {
#                 "x": 1280,
#                 "y": 699
#               },
#               {
#                 "x": 1205,
#                 "y": 711
#               }
#             ]
#           }
#         },
#         {
#           "description": "35",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1371,
#                 "y": 645
#               },
#               {
#                 "x": 1399,
#                 "y": 641
#               },
#               {
#                 "x": 1404,
#                 "y": 674
#               },
#               {
#                 "x": 1376,
#                 "y": 679
#               }
#             ]
#           }
#         },
#         {
#           "description": "季",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1506,
#                 "y": 618
#               },
#               {
#                 "x": 1567,
#                 "y": 609
#               },
#               {
#                 "x": 1573,
#                 "y": 647
#               },
#               {
#                 "x": 1512,
#                 "y": 657
#               }
#             ]
#           }
#         },
#         {
#           "description": "豆",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1574,
#                 "y": 613
#               },
#               {
#                 "x": 1635,
#                 "y": 604
#               },
#               {
#                 "x": 1641,
#                 "y": 641
#               },
#               {
#                 "x": 1580,
#                 "y": 651
#               }
#             ]
#           }
#         },
#         {
#           "description": "$",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1711,
#                 "y": 592
#               },
#               {
#                 "x": 1740,
#                 "y": 588
#               },
#               {
#                 "x": 1746,
#                 "y": 630
#               },
#               {
#                 "x": 1717,
#                 "y": 635
#               }
#             ]
#           }
#         },
#         {
#           "description": "12.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1771,
#                 "y": 586
#               },
#               {
#                 "x": 1922,
#                 "y": 563
#               },
#               {
#                 "x": 1928,
#                 "y": 604
#               },
#               {
#                 "x": 1777,
#                 "y": 627
#               }
#             ]
#           }
#         },
#         {
#           "description": "14.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 878,
#                 "y": 714
#               },
#               {
#                 "x": 1017,
#                 "y": 690
#               },
#               {
#                 "x": 1027,
#                 "y": 745
#               },
#               {
#                 "x": 888,
#                 "y": 769
#               }
#             ]
#           }
#         },
#         {
#           "description": "jr",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1340,
#                 "y": 708
#               },
#               {
#                 "x": 1378,
#                 "y": 702
#               },
#               {
#                 "x": 1383,
#                 "y": 740
#               },
#               {
#                 "x": 1346,
#                 "y": 746
#               }
#             ]
#           }
#         },
#         {
#           "description": "n",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1399,
#                 "y": 704
#               },
#               {
#                 "x": 1421,
#                 "y": 701
#               },
#               {
#                 "x": 1425,
#                 "y": 731
#               },
#               {
#                 "x": 1404,
#                 "y": 735
#               }
#             ]
#           }
#         },
#         {
#           "description": "-",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1438,
#                 "y": 691
#               },
#               {
#                 "x": 1456,
#                 "y": 688
#               },
#               {
#                 "x": 1463,
#                 "y": 733
#               },
#               {
#                 "x": 1445,
#                 "y": 735
#               }
#             ]
#           }
#         },
#         {
#           "description": "green",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1458,
#                 "y": 703
#               },
#               {
#                 "x": 1574,
#                 "y": 685
#               },
#               {
#                 "x": 1578,
#                 "y": 714
#               },
#               {
#                 "x": 1462,
#                 "y": 732
#               }
#             ]
#           }
#         },
#         {
#           "description": "beans",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1589,
#                 "y": 673
#               },
#               {
#                 "x": 1703,
#                 "y": 656
#               },
#               {
#                 "x": 1708,
#                 "y": 687
#               },
#               {
#                 "x": 1594,
#                 "y": 705
#               }
#             ]
#           }
#         },
#         {
#           "description": "$",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 95,
#                 "y": 835
#               },
#               {
#                 "x": 116,
#                 "y": 832
#               },
#               {
#                 "x": 121,
#                 "y": 870
#               },
#               {
#                 "x": 100,
#                 "y": 873
#               }
#             ]
#           }
#         },
#         {
#           "description": "13.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 137,
#                 "y": 825
#               },
#               {
#                 "x": 261,
#                 "y": 808
#               },
#               {
#                 "x": 266,
#                 "y": 846
#               },
#               {
#                 "x": 142,
#                 "y": 864
#               }
#             ]
#           }
#         },
#         {
#           "description": "jC5",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 330,
#                 "y": 794
#               },
#               {
#                 "x": 450,
#                 "y": 777
#               },
#               {
#                 "x": 456,
#                 "y": 822
#               },
#               {
#                 "x": 336,
#                 "y": 839
#               }
#             ]
#           }
#         },
#         {
#           "description": "山城",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 476,
#                 "y": 773
#               },
#               {
#                 "x": 593,
#                 "y": 757
#               },
#               {
#                 "x": 598,
#                 "y": 794
#               },
#               {
#                 "x": 481,
#                 "y": 811
#               }
#             ]
#           }
#         },
#         {
#           "description": "毛血旺",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 599,
#                 "y": 757
#               },
#               {
#                 "x": 791,
#                 "y": 730
#               },
#               {
#                 "x": 797,
#                 "y": 769
#               },
#               {
#                 "x": 604,
#                 "y": 796
#               }
#             ]
#           }
#         },
#         {
#           "description": "Pig",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 487,
#                 "y": 831
#               },
#               {
#                 "x": 530,
#                 "y": 826
#               },
#               {
#                 "x": 535,
#                 "y": 866
#               },
#               {
#                 "x": 492,
#                 "y": 872
#               }
#             ]
#           }
#         },
#         {
#           "description": "blood",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 547,
#                 "y": 824
#               },
#               {
#                 "x": 639,
#                 "y": 813
#               },
#               {
#                 "x": 644,
#                 "y": 853
#               },
#               {
#                 "x": 552,
#                 "y": 865
#               }
#             ]
#           }
#         },
#         {
#           "description": "in",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 653,
#                 "y": 809
#               },
#               {
#                 "x": 681,
#                 "y": 806
#               },
#               {
#                 "x": 686,
#                 "y": 846
#               },
#               {
#                 "x": 658,
#                 "y": 850
#               }
#             ]
#           }
#         },
#         {
#           "description": "chili",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 697,
#                 "y": 805
#               },
#               {
#                 "x": 766,
#                 "y": 797
#               },
#               {
#                 "x": 771,
#                 "y": 837
#               },
#               {
#                 "x": 702,
#                 "y": 846
#               }
#             ]
#           }
#         },
#         {
#           "description": "sauLE",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 783,
#                 "y": 794
#               },
#               {
#                 "x": 866,
#                 "y": 784
#               },
#               {
#                 "x": 871,
#                 "y": 825
#               },
#               {
#                 "x": 788,
#                 "y": 835
#               }
#             ]
#           }
#         },
#         {
#           "description": "ced",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1506,
#                 "y": 764
#               },
#               {
#                 "x": 1593,
#                 "y": 751
#               },
#               {
#                 "x": 1603,
#                 "y": 820
#               },
#               {
#                 "x": 1516,
#                 "y": 833
#               }
#             ]
#           }
#         },
#         {
#           "description": "pork",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1607,
#                 "y": 750
#               },
#               {
#                 "x": 1689,
#                 "y": 738
#               },
#               {
#                 "x": 1699,
#                 "y": 807
#               },
#               {
#                 "x": 1617,
#                 "y": 819
#               }
#             ]
#           }
#         },
#         {
#           "description": "11.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1776,
#                 "y": 725
#               },
#               {
#                 "x": 1930,
#                 "y": 702
#               },
#               {
#                 "x": 1941,
#                 "y": 771
#               },
#               {
#                 "x": 1786,
#                 "y": 794
#               }
#             ]
#           }
#         },
#         {
#           "description": "uce",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "y": 911
#               },
#               {
#                 "x": 54,
#                 "y": 911
#               },
#               {
#                 "x": 54,
#                 "y": 940
#               },
#               {
#                 "y": 940
#               }
#             ]
#           }
#         },
#         {
#           "description": "上",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 960,
#                 "y": 856
#               },
#               {
#                 "x": 1018,
#                 "y": 849
#               },
#               {
#                 "x": 1022,
#                 "y": 887
#               },
#               {
#                 "x": 964,
#                 "y": 894
#               }
#             ]
#           }
#         },
#         {
#           "description": "re.stdi",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1012,
#                 "y": 852
#               },
#               {
#                 "x": 1170,
#                 "y": 830
#               },
#               {
#                 "x": 1177,
#                 "y": 874
#               },
#               {
#                 "x": 1018,
#                 "y": 897
#               }
#             ]
#           }
#         },
#         {
#           "description": "ch",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1184,
#                 "y": 838
#               },
#               {
#                 "x": 1230,
#                 "y": 832
#               },
#               {
#                 "x": 1234,
#                 "y": 865
#               },
#               {
#                 "x": 1189,
#                 "y": 872
#               }
#             ]
#           }
#         },
#         {
#           "description": "noodle",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1237,
#                 "y": 831
#               },
#               {
#                 "x": 1361,
#                 "y": 814
#               },
#               {
#                 "x": 1365,
#                 "y": 842
#               },
#               {
#                 "x": 1241,
#                 "y": 860
#               }
#             ]
#           }
#         },
#         {
#           "description": "wi",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1378,
#                 "y": 811
#               },
#               {
#                 "x": 1416,
#                 "y": 806
#               },
#               {
#                 "x": 1420,
#                 "y": 833
#               },
#               {
#                 "x": 1382,
#                 "y": 839
#               }
#             ]
#           }
#         },
#         {
#           "description": "10.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 333,
#                 "y": 929
#               },
#               {
#                 "x": 475,
#                 "y": 912
#               },
#               {
#                 "x": 482,
#                 "y": 970
#               },
#               {
#                 "x": 340,
#                 "y": 987
#               }
#             ]
#           }
#         },
#         {
#           "description": "jC9",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 680,
#                 "y": 887
#               },
#               {
#                 "x": 805,
#                 "y": 873
#               },
#               {
#                 "x": 811,
#                 "y": 922
#               },
#               {
#                 "x": 686,
#                 "y": 936
#               }
#             ]
#           }
#         },
#         {
#           "description": ",",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 952,
#                 "y": 863
#               },
#               {
#                 "x": 958,
#                 "y": 862
#               },
#               {
#                 "x": 959,
#                 "y": 873
#               },
#               {
#                 "x": 954,
#                 "y": 874
#               }
#             ]
#           }
#         },
#         {
#           "description": ".-",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 960,
#                 "y": 885
#               },
#               {
#                 "x": 980,
#                 "y": 882
#               },
#               {
#                 "x": 981,
#                 "y": 889
#               },
#               {
#                 "x": 961,
#                 "y": 892
#               }
#             ]
#           }
#         },
#         {
#           "description": "Mapo",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "y": 994
#               },
#               {
#                 "x": 75,
#                 "y": 994
#               },
#               {
#                 "x": 75,
#                 "y": 1026
#               },
#               {
#                 "y": 1026
#               }
#             ]
#           }
#         },
#         {
#           "description": "tofu",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 87,
#                 "y": 975
#               },
#               {
#                 "x": 148,
#                 "y": 975
#               },
#               {
#                 "x": 148,
#                 "y": 1007
#               },
#               {
#                 "x": 87,
#                 "y": 1007
#               }
#             ]
#           }
#         },
#         {
#           "description": ".",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1407,
#                 "y": 943
#               },
#               {
#                 "x": 1413,
#                 "y": 942
#               },
#               {
#                 "x": 1414,
#                 "y": 948
#               },
#               {
#                 "x": 1408,
#                 "y": 949
#               }
#             ]
#           }
#         },
#         {
#           "description": "Fire",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1428,
#                 "y": 929
#               },
#               {
#                 "x": 1501,
#                 "y": 920
#               },
#               {
#                 "x": 1505,
#                 "y": 948
#               },
#               {
#                 "x": 1431,
#                 "y": 957
#               }
#             ]
#           }
#         },
#         {
#           "description": "Pot",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1517,
#                 "y": 915
#               },
#               {
#                 "x": 1582,
#                 "y": 907
#               },
#               {
#                 "x": 1586,
#                 "y": 935
#               },
#               {
#                 "x": 1520,
#                 "y": 943
#               }
#             ]
#           }
#         },
#         {
#           "description": "C10",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 742,
#                 "y": 1008
#               },
#               {
#                 "x": 848,
#                 "y": 995
#               },
#               {
#                 "x": 853,
#                 "y": 1033
#               },
#               {
#                 "x": 747,
#                 "y": 1047
#               }
#             ]
#           }
#         },
#         {
#           "description": "五",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 873,
#                 "y": 994
#               },
#               {
#                 "x": 932,
#                 "y": 987
#               },
#               {
#                 "x": 936,
#                 "y": 1022
#               },
#               {
#                 "x": 877,
#                 "y": 1030
#               }
#             ]
#           }
#         },
#         {
#           "description": "吏",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 936,
#                 "y": 982
#               },
#               {
#                 "x": 992,
#                 "y": 975
#               },
#               {
#                 "x": 997,
#                 "y": 1016
#               },
#               {
#                 "x": 941,
#                 "y": 1023
#               }
#             ]
#           }
#         },
#         {
#           "description": "肠",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1001,
#                 "y": 975
#               },
#               {
#                 "x": 1057,
#                 "y": 968
#               },
#               {
#                 "x": 1061,
#                 "y": 1006
#               },
#               {
#                 "x": 1006,
#                 "y": 1013
#               }
#             ]
#           }
#         },
#         {
#           "description": "EE",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1065,
#                 "y": 968
#               },
#               {
#                 "x": 1120,
#                 "y": 961
#               },
#               {
#                 "x": 1124,
#                 "y": 996
#               },
#               {
#                 "x": 1069,
#                 "y": 1003
#               }
#             ]
#           }
#         },
#         {
#           "description": "Pork",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1148,
#                 "y": 967
#               },
#               {
#                 "x": 1237,
#                 "y": 956
#               },
#               {
#                 "x": 1241,
#                 "y": 985
#               },
#               {
#                 "x": 1152,
#                 "y": 996
#               }
#             ]
#           }
#         },
#         {
#           "description": "Intest",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1252,
#                 "y": 953
#               },
#               {
#                 "x": 1356,
#                 "y": 940
#               },
#               {
#                 "x": 1360,
#                 "y": 971
#               },
#               {
#                 "x": 1256,
#                 "y": 984
#               }
#             ]
#           }
#         },
#         {
#           "description": "Beef",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "y": 1098
#               },
#               {
#                 "x": 55,
#                 "y": 1091
#               },
#               {
#                 "x": 62,
#                 "y": 1150
#               },
#               {
#                 "x": 8,
#                 "y": 1157
#               }
#             ]
#           }
#         },
#         {
#           "description": "in",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 67,
#                 "y": 1089
#               },
#               {
#                 "x": 87,
#                 "y": 1086
#               },
#               {
#                 "x": 95,
#                 "y": 1146
#               },
#               {
#                 "x": 75,
#                 "y": 1148
#               }
#             ]
#           }
#         },
#         {
#           "description": "flery",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 108,
#                 "y": 1084
#               },
#               {
#                 "x": 170,
#                 "y": 1076
#               },
#               {
#                 "x": 178,
#                 "y": 1135
#               },
#               {
#                 "x": 116,
#                 "y": 1143
#               }
#             ]
#           }
#         },
#         {
#           "description": "sauce",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 195,
#                 "y": 1071
#               },
#               {
#                 "x": 278,
#                 "y": 1060
#               },
#               {
#                 "x": 286,
#                 "y": 1119
#               },
#               {
#                 "x": 203,
#                 "y": 1130
#               }
#             ]
#           }
#         },
#         {
#           "description": "$",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 312,
#                 "y": 1056
#               },
#               {
#                 "x": 332,
#                 "y": 1053
#               },
#               {
#                 "x": 340,
#                 "y": 1113
#               },
#               {
#                 "x": 320,
#                 "y": 1115
#               }
#             ]
#           }
#         },
#         {
#           "description": "13.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 355,
#                 "y": 1050
#               },
#               {
#                 "x": 492,
#                 "y": 1032
#               },
#               {
#                 "x": 500,
#                 "y": 1091
#               },
#               {
#                 "x": 363,
#                 "y": 1109
#               }
#             ]
#           }
#         },
#         {
#           "description": "Hot",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 74,
#                 "y": 1330
#               },
#               {
#                 "x": 169,
#                 "y": 1319
#               },
#               {
#                 "x": 173,
#                 "y": 1355
#               },
#               {
#                 "x": 78,
#                 "y": 1366
#               }
#             ]
#           }
#         },
#         {
#           "description": "Pot",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 185,
#                 "y": 1316
#               },
#               {
#                 "x": 278,
#                 "y": 1306
#               },
#               {
#                 "x": 282,
#                 "y": 1341
#               },
#               {
#                 "x": 189,
#                 "y": 1352
#               }
#             ]
#           }
#         },
#         {
#           "description": "y",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "y": 1978
#               },
#               {
#                 "x": 16,
#                 "y": 1978
#               },
#               {
#                 "x": 16,
#                 "y": 2020
#               },
#               {
#                 "y": 2020
#               }
#             ]
#           }
#         },
#         {
#           "description": "鸡",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 22,
#                 "y": 1978
#               },
#               {
#                 "x": 69,
#                 "y": 1978
#               },
#               {
#                 "x": 69,
#                 "y": 2018
#               },
#               {
#                 "x": 22,
#                 "y": 2018
#               }
#             ]
#           }
#         },
#         {
#           "description": "hicker",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1,
#                 "y": 2044
#               },
#               {
#                 "x": 85,
#                 "y": 2040
#               },
#               {
#                 "x": 86,
#                 "y": 2076
#               },
#               {
#                 "x": 3,
#                 "y": 2080
#               }
#             ]
#           }
#         },
#         {
#           "description": "in",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 106,
#                 "y": 2040
#               },
#               {
#                 "x": 130,
#                 "y": 2039
#               },
#               {
#                 "x": 132,
#                 "y": 2075
#               },
#               {
#                 "x": 108,
#                 "y": 2076
#               }
#             ]
#           }
#         },
#         {
#           "description": "hot",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 146,
#                 "y": 2037
#               },
#               {
#                 "x": 197,
#                 "y": 2035
#               },
#               {
#                 "x": 199,
#                 "y": 2071
#               },
#               {
#                 "x": 148,
#                 "y": 2073
#               }
#             ]
#           }
#         },
#         {
#           "description": "pot",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 210,
#                 "y": 2034
#               },
#               {
#                 "x": 261,
#                 "y": 2032
#               },
#               {
#                 "x": 263,
#                 "y": 2068
#               },
#               {
#                 "x": 212,
#                 "y": 2070
#               }
#             ]
#           }
#         },
#         {
#           "description": "313.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 151,
#                 "y": 1974
#               },
#               {
#                 "x": 328,
#                 "y": 1961
#               },
#               {
#                 "x": 331,
#                 "y": 2003
#               },
#               {
#                 "x": 154,
#                 "y": 2016
#               }
#             ]
#           }
#         },
#         {
#           "description": "丿",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 395,
#                 "y": 1954
#               },
#               {
#                 "x": 433,
#                 "y": 1951
#               },
#               {
#                 "x": 437,
#                 "y": 2002
#               },
#               {
#                 "x": 399,
#                 "y": 2005
#               }
#             ]
#           }
#         },
#         {
#           "description": "D2",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 447,
#                 "y": 1951
#               },
#               {
#                 "x": 530,
#                 "y": 1945
#               },
#               {
#                 "x": 533,
#                 "y": 1988
#               },
#               {
#                 "x": 450,
#                 "y": 1994
#               }
#             ]
#           }
#         },
#         {
#           "description": "干锅",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 555,
#                 "y": 1943
#               },
#               {
#                 "x": 679,
#                 "y": 1934
#               },
#               {
#                 "x": 682,
#                 "y": 1980
#               },
#               {
#                 "x": 558,
#                 "y": 1989
#               }
#             ]
#           }
#         },
#         {
#           "description": "茶树菇",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 684,
#                 "y": 1929
#               },
#               {
#                 "x": 875,
#                 "y": 1915
#               },
#               {
#                 "x": 878,
#                 "y": 1960
#               },
#               {
#                 "x": 687,
#                 "y": 1974
#               }
#             ]
#           }
#         },
#         {
#           "description": "$",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 944,
#                 "y": 1911
#               },
#               {
#                 "x": 973,
#                 "y": 1909
#               },
#               {
#                 "x": 976,
#                 "y": 1954
#               },
#               {
#                 "x": 947,
#                 "y": 1956
#               }
#             ]
#           }
#         },
#         {
#           "description": "14.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1002,
#                 "y": 1906
#               },
#               {
#                 "x": 1148,
#                 "y": 1896
#               },
#               {
#                 "x": 1151,
#                 "y": 1941
#               },
#               {
#                 "x": 1005,
#                 "y": 1951
#               }
#             ]
#           }
#         },
#         {
#           "description": "jD3",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1247,
#                 "y": 1885
#               },
#               {
#                 "x": 1392,
#                 "y": 1875
#               },
#               {
#                 "x": 1396,
#                 "y": 1930
#               },
#               {
#                 "x": 1251,
#                 "y": 1940
#               }
#             ]
#           }
#         },
#         {
#           "description": "干锅",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1421,
#                 "y": 1881
#               },
#               {
#                 "x": 1559,
#                 "y": 1871
#               },
#               {
#                 "x": 1562,
#                 "y": 1917
#               },
#               {
#                 "x": 1424,
#                 "y": 1927
#               }
#             ]
#           }
#         },
#         {
#           "description": "杏鲍菇",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1567,
#                 "y": 1868
#               },
#               {
#                 "x": 1778,
#                 "y": 1853
#               },
#               {
#                 "x": 1782,
#                 "y": 1901
#               },
#               {
#                 "x": 1570,
#                 "y": 1916
#               }
#             ]
#           }
#         },
#         {
#           "description": "$",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1859,
#                 "y": 1853
#               },
#               {
#                 "x": 1893,
#                 "y": 1851
#               },
#               {
#                 "x": 1896,
#                 "y": 1899
#               },
#               {
#                 "x": 1862,
#                 "y": 1902
#               }
#             ]
#           }
#         },
#         {
#           "description": "14.95",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 1923,
#                 "y": 1847
#               },
#               {
#                 "x": 2089,
#                 "y": 1835
#               },
#               {
#                 "x": 2092,
#                 "y": 1881
#               },
#               {
#                 "x": 1926,
#                 "y": 1893
#               }
#             ]
#           }
#         },
#         {
#           "description": "Tea",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 556,
#                 "y": 2009
#               },
#               {
#                 "x": 623,
#                 "y": 2004
#               },
#               {
#                 "x": 625,
#                 "y": 2036
#               },
#               {
#                 "x": 558,
#                 "y": 2041
#               }
#             ]
#           }
#         },
#         {
#           "description": "tree",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 639,
#                 "y": 2003
#               },
#               {
#                 "x": 712,
#                 "y": 1997
#               },
#               {
#                 "x": 714,
#                 "y": 2028
#               },
#               {
#                 "x": 641,
#                 "y": 2034
#               }
#             ]
#           }
#         },
#         {
#           "description": "Mushroom",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 728,
#                 "y": 1995
#               },
#               {
#                 "x": 918,
#                 "y": 1980
#               },
#               {
#                 "x": 921,
#                 "y": 2012
#               },
#               {
#                 "x": 730,
#                 "y": 2027
#               }
#             ]
#           }
#         },
#         {
#           "description": "in",
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 932,
#                 "y": 1981
#               },
#               {
#                 "x": 964,
#                 "y": 1979
#               },
#               {
#                 "x": 966,
#                 "y": 2010
#               },
#               {
#                 "x": 934,
#                 "y": 2013
# ...
#                                 },
#                                 {
#                                   "x": 1771,
#                                   "y": 2673
#                                 },
#                                 {
#                                   "x": 1772,
#                                   "y": 2701
#                                 },
#                                 {
#                                   "x": 1764,
#                                   "y": 2701
#                                 }
#                               ]
#                             },
#                             "text": ":"
#                           }
#                         ]
#                       },
#                       {
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 1794,
#                               "y": 2649
#                             },
#                             {
#                               "x": 2154,
#                               "y": 2637
#                             },
#                             {
#                               "x": 2155,
#                               "y": 2683
#                             },
#                             {
#                               "x": 1796,
#                               "y": 2695
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 1794,
#                                   "y": 2657
#                                 },
#                                 {
#                                   "x": 1825,
#                                   "y": 2656
#                                 },
#                                 {
#                                   "x": 1826,
#                                   "y": 2694
#                                 },
#                                 {
#                                   "x": 1795,
#                                   "y": 2695
#                                 }
#                               ]
#                             },
#                             "text": "4"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 1826,
#                                   "y": 2656
#                                 },
#                                 {
#                                   "x": 1857,
#                                   "y": 2655
#                                 },
#                                 {
#                                   "x": 1858,
#                                   "y": 2693
#                                 },
#                                 {
#                                   "x": 1827,
#                                   "y": 2694
#                                 }
#                               ]
#                             },
#                             "text": "0"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 1866,
#                                   "y": 2653
#                                 },
#                                 {
#                                   "x": 1894,
#                                   "y": 2652
#                                 },
#                                 {
#                                   "x": 1895,
#                                   "y": 2690
#                                 },
#                                 {
#                                   "x": 1867,
#                                   "y": 2691
#                                 }
#                               ]
#                             },
#                             "text": "8"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 1901,
#                                   "y": 2650
#                                 },
#                                 {
#                                   "x": 1926,
#                                   "y": 2649
#                                 },
#                                 {
#                                   "x": 1927,
#                                   "y": 2685
#                                 },
#                                 {
#                                   "x": 1902,
#                                   "y": 2686
#                                 }
#                               ]
#                             },
#                             "text": "-"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 1927,
#                                   "y": 2650
#                                 },
#                                 {
#                                   "x": 1949,
#                                   "y": 2649
#                                 },
#                                 {
#                                   "x": 1950,
#                                   "y": 2685
#                                 },
#                                 {
#                                   "x": 1928,
#                                   "y": 2686
#                                 }
#                               ]
#                             },
#                             "text": "7"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 1957,
#                                   "y": 2647
#                                 },
#                                 {
#                                   "x": 1989,
#                                   "y": 2646
#                                 },
#                                 {
#                                   "x": 1990,
#                                   "y": 2682
#                                 },
#                                 {
#                                   "x": 1958,
#                                   "y": 2683
#                                 }
#                               ]
#                             },
#                             "text": "4"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 1991,
#                                   "y": 2646
#                                 },
#                                 {
#                                   "x": 2023,
#                                   "y": 2645
#                                 },
#                                 {
#                                   "x": 2024,
#                                   "y": 2681
#                                 },
#                                 {
#                                   "x": 1992,
#                                   "y": 2682
#                                 }
#                               ]
#                             },
#                             "text": "0"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 2033,
#                                   "y": 2643
#                                 },
#                                 {
#                                   "x": 2057,
#                                   "y": 2642
#                                 },
#                                 {
#                                   "x": 2058,
#                                   "y": 2678
#                                 },
#                                 {
#                                   "x": 2034,
#                                   "y": 2679
#                                 }
#                               ]
#                             },
#                             "text": "-"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 2058,
#                                   "y": 2643
#                                 },
#                                 {
#                                   "x": 2083,
#                                   "y": 2642
#                                 },
#                                 {
#                                   "x": 2084,
#                                   "y": 2678
#                                 },
#                                 {
#                                   "x": 2059,
#                                   "y": 2679
#                                 }
#                               ]
#                             },
#                             "text": "5"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ]
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 2089,
#                                   "y": 2640
#                                 },
#                                 {
#                                   "x": 2117,
#                                   "y": 2639
#                                 },
#                                 {
#                                   "x": 2118,
#                                   "y": 2675
#                                 },
#                                 {
#                                   "x": 2090,
#                                   "y": 2676
#                                 }
#                               ]
#                             },
#                             "text": "3"
#                           },
#                           {
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "zh-Hans"
#                                 }
#                               ],
#                               "detectedBreak": {
#                                 "type": "EOL_SURE_SPACE"
#                               }
#                             },
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 2126,
#                                   "y": 2638
#                                 },
#                                 {
#                                   "x": 2153,
#                                   "y": 2637
#                                 },
#                                 {
#                                   "x": 2154,
#                                   "y": 2675
#                                 },
#                                 {
#                                   "x": 2127,
#                                   "y": 2676
#                                 }
#                               ]
#                             },
#                             "text": "5"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ],
#                 "blockType": "TEXT"
#               }
#             ]
#           }
#         ],
#         "text": "$ 13.95\n.. $ 13.95\nj C3宮保鸡丁.\nKung Pao chicken\n-\nJC2費香肉丝\n$13.\nPork with splcy garlic\nC6 35 季豆 $ 12.95\n14.95\njr n-green beans\n$ 13.95 jC5山城毛血旺\nPig blood in chili sauLE\nced pork 11.95\nuce\n上\nre.stdi ch noodle wi\n10.95\njC9\n,.-\nMapo\ntofu\n. Fire Pot\nC10五吏肠EE Pork Intest\nBeef in flery sauce $ 13.95\nHot Pot\ny鸡\nhicker in hot pot\n313.95 丿D2干锅茶树菇 $ 14.95\njD3干锅杏鲍菇 $ 14.95\nTea tree Mushroom in hot pot\nCoprinuscomatus in hot pot\n束鸡\nn in hot\n$13.95\njD7麻辣烫锅\n14.95\nSpicy Combination hot pot\n肚\nn hot pot\n$14.95\nJD8麻辣牛腩锅\n$ 14.95\nSpicy beef stew in hot pot\n$ 14.95\nestine in hot pot\nD9酸菜鱼羊锅\n14.95\nPickled mustard with fish and lamb\noduction\n·前制竹\nEi -il: Forwardpro328@gmail.com.\nTel: 408-740-535\n"
#       }
#     }
#   ]
# }
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-ecace3b36e6e> in <module>()
#      18 print(textResp.text)
#      19
# ---> 20 raise Exception("Stop to look at the results!!!")
#
# Exception: Stop to look at the results!!!

# %% [markdown]
# ##Try translation API

# %%
import json
loaded_json = json.loads(textResp.text)
extract = loaded_json['responses'][0]['textAnnotations'][0]['description']
transJson = {
  "q": "{}".format(extract),
  "target": "en"
}

# %%
resp = requests.post('https://translation.googleapis.com/language/translate/v2?key={0}'.format(pAPI_KEY), json=transJson)
print(transJson)
print(resp.text)
# Out:
# {'q': '$ 13.95\n.. $ 13.95\nj C3宮保鸡丁.\nKung Pao chicken\n-\nJC2費香肉丝\n$13.\nPork with splcy garlic\nC6 35 季豆 $ 12.95\n14.95\njr n-green beans\n$ 13.95 jC5山城毛血旺\nPig blood in chili sauLE\nced pork 11.95\nuce\n上\nre.stdi ch noodle wi\n10.95\njC9\n,.-\nMapo\ntofu\n. Fire Pot\nC10五吏肠EE Pork Intest\nBeef in flery sauce $ 13.95\nHot Pot\ny鸡\nhicker in hot pot\n313.95 丿D2干锅茶树菇 $ 14.95\njD3干锅杏鲍菇 $ 14.95\nTea tree Mushroom in hot pot\nCoprinuscomatus in hot pot\n束鸡\nn in hot\n$13.95\njD7麻辣烫锅\n14.95\nSpicy Combination hot pot\n肚\nn hot pot\n$14.95\nJD8麻辣牛腩锅\n$ 14.95\nSpicy beef stew in hot pot\n$ 14.95\nestine in hot pot\nD9酸菜鱼羊锅\n14.95\nPickled mustard with fish and lamb\noduction\n·前制竹\nEi -il: Forwardpro328@gmail.com.\nTel: 408-740-535\n', 'target': 'en'}
# {
#   "data": {
#     "translations": [
#       {
#         "translatedText": "$ 13.95 .. $ 13.95 j C3 Kung Pao Chicken. Kung Pao chicken - JC2 Fragrant Pork $13. Pork with splcy garlic C6 35 Season Beans $ 12.95 14.95 jr n-green beans $ 13.95 jC5 山城毛血旺 Pig blood in chili sauLE ced pork 11.95 uce on re.stdi ch noodle wi 10.95 jC9 ,.- Mapo tofu . Fire Pot C10 吏 EE Pork Intest Beef in flery sauce $ 13.95 Hot Pot y chicken hicker in hot pot 313.95 丿D2 dry pot tea tree mushroom $ 14.95 jD3 dry pot oyster mushroom $ 14.95 Tea tree Mushroom in hot pot Coprinuscomatus in hot pot bunch chicken n in hot $13.95 jD7 spicy hot pot 14.95 Spicy Combination hot pot belly n hot pot $14.95 JD8 spicy beef shabu-shabu $ 14.95 Spicy beef stew in Hot pot $ 14.95 estine in hot pot D9 pickled mustard with fish and lamb oduction 14. Pre-made bamboo Ei -il: Forwardpro328@gmail.com. Tel: 408-740-535",
#         "detectedSourceLanguage": "zh-TW"
#       }
#     ]
#   }
# }
